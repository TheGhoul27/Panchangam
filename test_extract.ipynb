# %%
from bs4 import BeautifulSoup as bs
import requests as req
from tabulate import tabulate
import datetime
import json

#css = "td+ td"
css = "td"
url = "https://www.panchangam.org/global/daily.php?city=New+York#google_vignette"

day_map = {
    'Monday': 'Indu Vasara',
    'Tuesday': 'Bhauma Vasara',
    'Wednesday': 'Saumya Vasara',
    'Thursday': 'Guru Vasara',
    'Friday': 'Bhrigu Vasara',
    'Saturday': 'Sthira Vasara',
    'Sunday': 'Bhanu Vasara'
}

ruthu_map = {
    'Chaithra': 'Vasanta Ruthu',
    'Vaisakha': 'Vasanta Ruthu',
    'Jyeshta': 'Greeshma Ruthu',
    'Ashadha': 'Greeshma Ruthu',
    'Sravana': 'Greeshma Ruthu',
    'Bhadrapada': 'Greeshma Ruthu',
    'Ashvina': 'Sharada Ruthu',
    'Kartika': 'Sharada Ruthu',
    'Agrahayana': 'Hemanta Ruthu',
    'Pausa': 'Hemanta Ruthu',
    'Magha': 'Shishira Ruthu',
    'Phalguna': 'Shishira Ruthu'
}

def get_panchangam(url):
    page = req.get(url)
    soup = bs(page.content, "html.parser")
    panchangam = soup.select(css)
    return panchangam

panchangam = get_panchangam(url)

all_vals = []
for i in panchangam:
    all_vals.append(i.text)

today = datetime.date.today()
weekday_number = today.weekday()
weekday_name = datetime.date.today().strftime("%A")

title = all_vals[0]

col1 = ['Samvatsara']
col2 = ['Krodhi Nama Samvatsara']

skip = 0
for i in range(1, len(all_vals)):
    if all_vals[i] in ['Panchangam', 'Time to Avoid (Bad time to start any important work)', 'Good Time (to start any important work)']:
        continue
    elif skip % 2 != 0:
        col2.append(all_vals[i])
        skip += 1
    else:
        col1.append(all_vals[i])
        skip += 1

table = zip(col1, col2)


maps = {
    'Title': title,
}

for a, b in zip(col1, col2):
    if a == 'Month':
        maps['Masa'] = b
        maps['Ruthu'] = ruthu_map[b]
        maps['Vasara'] = day_map[weekday_name]
    else:
        if a in ['Tithi', 'Nakshatram', 'Yogam', 'Karanam']:
            b = b.replace('  ', '\n')
        maps[a] = b

details = f'City: {maps["City"]}, Sunrise: {maps["Sunrise"]}, Sunset: {maps["Sunset"]}'
maps['Details'] = details
maps.pop('City', None)
maps.pop('Sunrise', None)
maps.pop('Sunset', None)


for key, value in maps.items():
    print(f'{key}: {value}')
# Out:
# Today's Panchangam - May 18, 2024 (Saturday)
# Title: Today's Panchangam - May 18, 2024 (Saturday)
# Samvatsara: Krodhi Nama Samvatsara
# Masa: Vaisakha
# Ruthu: Vasanta Ruthu
# Vasara: Sthira Vasara
# Paksham: Sukla Paksha
# Tithi: Ekadashi : May 18 01:53 AM to May 19 04:20 AM
# Dwadashi : May 19 04:20 AM to May 20 06:29 AM
# Nakshatram: Uttara Phalguni: May 17 11:48 AM to May 18 02:53 PM Hasta: May 18 02:53 PM to May 19 05:46 PM
# Yogam: Vajra: May 18 12:54 AM to May 19 01:54 AM Siddhi: May 19 01:54 AM to May 20 02:40 AM
# Karanam: Vanija: May 18 01:53 AM to May 18 03:08 PM Vishti: May 18 03:08 PM to May 19 04:20 AM Bava: May 19 04:20 AM to May 19 05:27 PM
# Rahukalam: 9:16 AM to 11:04 AM
# Yamagandam: 2:40 PM to 4:28 PM
# Varjyam: 12:17 AM to 02:05 AM
# Gulika: 5:40 AM to 7:28 AM
# Amritakalam: 06:45 AM to 08:34 AM
# Abhijit Muhurtham: 12:23 PM to 01:21 PM
# Details: City: New York, Sunrise: 5:40 AM, Sunset: 8:04 PM
